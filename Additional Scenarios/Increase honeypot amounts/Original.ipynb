# %%
# --- CUDA DEVICE SETUP ---
import torch

from utils.basic_utils import add_timestamp_to_edges

# Tự động chọn GPU nếu có
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Khi cần chuyển dữ liệu: 
# tensor = tensor.to(device)
# model = model.to(device)
# g = g.to(device)
# Out:
# Using device: cuda

# %%
import networkx as nx
import dgl
import torch
import numpy as np
from utils.basic_utils import *
# --- 1. TẠO DỮ LIỆU ĐỒ THỊ MẠNG ---

# Khởi tạo NetworkX Graph
G_original = nx.DiGraph()
G_original.add_nodes_from(["Data Server", "Pad", "Web Server", "Host 1", "Host 2", "Host 3", "File Server", "Print Server"])

# Node Attributes
node_attributes = {
    "Data Server": {"state": 0, "priority": 2}, "Pad": {"state": 0, "priority": 1},
    "Web Server": {"state": 0, "priority": 1}, "Host 1": {"state": 0, "priority": 1},
    "Host 2": {"state": 0, "priority": 0}, "Host 3": {"state": 0, "priority": 0},
    "File Server": {"state": 0, "priority": 0}, "Print Server": {"state": 0, "priority": 0}
}
nx.set_node_attributes(G_original, node_attributes)

# Raw Edges
raw_edges = [
    ("Pad", "Host 1", {"user": 0.6, "root": 0.48}),
    ("Pad", "Host 2", {"user": 0.32, "root": 0.32}),
    ("Pad", "Host 3", {"user": 0.32, "root": 0.32}),
    ("Pad", "Web Server", {"user": 0.8, "root": 0.6}),
    ("Host 1", "Pad", {"user": 0.6, "root": 0.6}),
    ("Host 1", "Web Server", {"user": 0.8, "root": 0.6}),
    ("Host 1", "Host 2", {"user": 0.32, "root": 0.32}),
    ("Host 1", "Host 3", {"user": 0.32, "root": 0.32}),
    ("Host 2", "Host 3", {"user": 0.8, "root": 0.8}),
    ("Host 2", "File Server", {"user": 0.8, "root": 0.6}),
    ("Host 2", "Data Server", {"user": 0.8, "root": 0.6}),
    ("Host 3", "Host 2", {"user": 0.8, "root": 0.8}),
    ("Host 3", "File Server", {"user": 0.8, "root": 0.6}),
    ("Host 3", "Data Server", {"user": 0.8, "root": 0.6}),
    ("Web Server", "File Server", {"user": 0.8, "root": 0.04}),
    ("Web Server", "Data Server", {"user": 0.8, "root": 0.04}),
    ("File Server", "Data Server", {"user": 0.8, "root": 0.04}),
    ("Data Server", "File Server", {"user": 0.6, "root": 0.02}),
    ("Host 2", "Print Server", {"user": 0.7, "root": 0.5}),
    ("Host 3", "Print Server", {"user": 0.7, "root": 0.5}),
    ("Print Server", "File Server", {"user": 0.6, "root": 0.4}),
    ("File Server", "Print Server", {"user": 0.8, "root": 0.8}),
]

# --- 2. XỬ LÝ & CONVERT SANG DGL ---

# Bước A: Xử lý timestamp và sort
sorted_edges_list = add_timestamp_to_edges(raw_edges)
# Thêm vào NX để lưu trữ logic (tuỳ chọn, vì hàm build_ordered_dgl dùng sorted_edges_list trực tiếp)
G_original.add_edges_from(sorted_edges_list)

# Bước B: Tạo DGL Graph chuẩn (Thay thế dgl.from_networkx)
# Lưu ý: Ta truyền key features vào để hàm tự trích xuất
g_dgl, node_order, node_map = build_dgl(
    nx_graph=G_original,
    sorted_edges=sorted_edges_list,
    node_feat_keys=['state', 'priority'], # Tạo nfeats
    edge_feat_keys=['user', 'root']       # Tạo efeats (bỏ qua timestamp)
)

# Lấy lại feature từ DGL để dùng cho các biến bên dưới (nếu cần)
nfeats = g_dgl.ndata['h']
efeats = g_dgl.edata['h']

# Tạo static priority (Cột số 1 của nfeats: 'priority')
static_priority_features = nfeats[:, 1].unsqueeze(1)

# --- 3. IN KẾT QUẢ ---
print("--- ĐỒ THỊ MẠNG ---")
print(f"Đã tạo g_dgl: {g_dgl.num_nodes()} nodes, {g_dgl.num_edges()} edges.")
print(f"Shape Đặc trưng Node (nfeats): {nfeats.shape}")
print(f"Shape Đặc trưng Edge (efeats): {efeats.shape}")

print(f"\nNode Order g_dgl (Ánh xạ Index -> Tên):\n{node_order}")
print(f"\nNode Map g_dgl (Ánh xạ Tên -> Index):\n{node_map}")

print("\n" + "="*30 + "\n")

print(f"Tổng số node: {len(node_order)}")
print(f"Shape của Static Priority Features: {static_priority_features.shape}")
# Out:
# --- ĐỒ THỊ MẠNG ---
# Đã tạo g_dgl: 8 nodes, 22 edges.
# Shape Đặc trưng Node (nfeats): torch.Size([8, 2])
# Shape Đặc trưng Edge (efeats): torch.Size([22, 2])
#
# Node Order g_dgl (Ánh xạ Index -> Tên):
# ['Data Server', 'Pad', 'Web Server', 'Host 1', 'Host 2', 'Host 3', 'File Server', 'Print Server']
#
# Node Map g_dgl (Ánh xạ Tên -> Index):
# {'Data Server': 0, 'Pad': 1, 'Web Server': 2, 'Host 1': 3, 'Host 2': 4, 'Host 3': 5, 'File Server': 6, 'Print Server': 7}
#
# ==============================
#
# Tổng số node: 8
# Shape của Static Priority Features: torch.Size([8, 1])

# %% [markdown]
# ## Sổ tay Tác nhân RL (Đã sửa lỗi)
#
# Sổ tay này tải môi trường, cấu hình GNN, và trọng số GNN đã huấn luyện (từ `Graph_Canonical_50.ipynb`) để chạy Tác nhân DQN.

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import dgl
import os
from copy import deepcopy
from collections import defaultdict
import random
import yaml

# Giả định các tệp utils này tồn tại trong thư mục của bạn
from utils.attack_algo_utils import *
from utils.graph_utils import *
from utils.basic_utils import *
from utils.model_utils import *

print("--- CHUẨN BỊ MÔI TRƯỜNG ---")

# --- CHỌN PHIÊN BẢN THÍ NGHIỆM ---
experiment_id = 1
BASE_PATH = f'graphs/{experiment_id}'
print(f"Đang chạy thí nghiệm ID: {experiment_id} tại đường dẫn: {BASE_PATH}")
# Out:
# --- CHUẨN BỊ MÔI TRƯỜNG ---
# Đang chạy thí nghiệm ID: 1 tại đường dẫn: graphs/1

# %%
# ======================================================================
# 2. ĐỊNH NGHĨA HÀM TIỀN XỬ LÝ (PHẢI GIỐNG HỆT FILE HUẤN LUYỆN)
# ======================================================================
# (Chúng ta cần các hằng số và hàm này để xử lý

MAX_N_FEATURES = 2
MAX_E_FEATURES = 2

def build_batch_tensor(feats, max_dim):
    return feats[:, :max_dim]

# %%
# ======================================================================
# 3. TẢI MODEL GNN ĐÃ HUẤN LUYỆN (PHẦN ĐÃ SỬA)
# ======================================================================
print("\n--- Đang tải cấu hình và trọng số GNN ---")

MODEL_STATE_PATH = f"graphs/dgi_model_state_dict.pth"
CONFIG_FILE_PATH = f"graphs/model_config.yaml"

try:
    with open(CONFIG_FILE_PATH, 'r') as file:
        config = yaml.safe_load(file)

    # --- 3.2: Khởi tạo mô hình rỗng TỪ CẤU HÌNH ĐÃ TẢI ---
    encoder = EGraphSAGE(
        config['NDIM_IN'],       # 50
        config['EDIM'],          # 50
        config['N_HIDDEN'],
        config['N_OUT'],
        config['N_LAYERS'],
        F.leaky_relu,
        device,
    )

    dgi_model_to_load = DGI(encoder)

    # --- 3.3: Tải trọng số đã lưu ---
    dgi_model_to_load.load_state_dict(torch.load(MODEL_STATE_PATH, weights_only=False))

    # --- 3.4: Trích xuất encoder bạn cần ---
    trained_encoder = dgi_model_to_load.encoder
    trained_encoder.to(device)
    trained_encoder.eval() # Chuyển sang chế độ dự đoán

    print(f"[THÀNH CÔNG] Đã tải và trích xuất GNN encoder.")

except Exception as e:
    print(f"\n[LỖI] Có lỗi xảy ra khi tải model: {e}")
    trained_encoder = None
# Out:
# --- Đang tải cấu hình và trọng số GNN ---
# [THÀNH CÔNG] Đã tải và trích xuất GNN encoder.

# %%
def train_dqn(env, num_episodes, device=None, batch_size=10, gamma=0.99,
              epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995):
    
    global best_checkpoint, best_episode

    # --- Reset env lấy state ban đầu ---
    state = env.reset().to(device)

    # [FIX] Tính state_size dựa trên kích thước thực tế của dữ liệu
    # State lúc này bao gồm cả Node và Edge embeddings
    # Dù state là 1D hay 2D, numel() sẽ trả về tổng số phần tử (ví dụ 1440)
    state_size = state.numel()

    # Lấy embedding_dim (chỉ để tham khảo hoặc log)
    if len(state.shape) > 1:
        embedding_dim = state.shape[-1]
    else:
        # Nếu state đã flatten rồi thì cần lấy từ env hoặc config
        embedding_dim = env.embedding_dim

    num_honeypots_N = env.num_honeypots
    # Lưu ý: max_nodes_M chỉ dùng cho đầu ra action, không dùng tính state_size nữa
    max_nodes_M = env.max_nodes

    print(f"Embedding Dim: {embedding_dim}")
    print(f"Actual State Shape from Env: {state.shape}")
    print(f"Calculated State Size (Input to DQN): {state_size}")
    print(f"Action Output Shape: ({num_honeypots_N}, {max_nodes_M})")

    # --- Khởi tạo mô hình với state_size đã sửa ---
    policy_net = MultiHeadDQN(state_size, num_honeypots_N, max_nodes_M).to(device)
    target_net = MultiHeadDQN(state_size, num_honeypots_N, max_nodes_M).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=0.001)
    replay_buffer = ReplayBuffer(capacity=10000)

    epsilon = epsilon_start
    total_reward = 0
    dsp = 0
    best_dsp = 0

    interval_check = max(1, num_episodes // 10)
    interval_save = max(1, num_episodes // 5)
    best_checkpoint = None
    best_episode = 0

    for episode in range(1, num_episodes + 1):
        if episode > 1:
            state = env.reset().to(device)

        done = False
        current_num_nodes = len(env.nodes)

        while not done:
            # --- Chọn action ---
            if random.random() < epsilon:
                # Random trong vùng node thật
                action = sample_valid_action_matrix(num_honeypots_N, current_num_nodes)

                # Pad action về đúng kích thước (N, M)
                full_action = np.zeros((num_honeypots_N, max_nodes_M), dtype=np.float32)
                full_action[:, :current_num_nodes] = action
                action = full_action
            else:
                # Policy
                with torch.no_grad():
                    # Flatten state để đưa vào mạng
                    # state có thể là (60, 24) hoặc (1440,), flatten sẽ ra (1440,)
                    # unsqueeze(0) -> (1, 1440)
                    state_tensor = state.flatten().unsqueeze(0).to(device)

                    q_values = policy_net(state_tensor)

                    # Masking
                    if current_num_nodes < q_values.shape[-1]:
                        q_values[:, :, current_num_nodes:] = -float('inf')

                    action = select_action_multi_head(q_values.squeeze(0), current_num_nodes)

            # --- Step ---
            next_state, reward, done, path, captured = env.step(action)
            next_state = next_state.to(device)

            # --- Push Buffer ---
            replay_buffer.push(state, action, reward, next_state, done)

            state = next_state
            total_reward += reward
            if reward == 1:
                dsp += 1

            # --- Training ---
            if len(replay_buffer) >= batch_size:
                states_batch, actions_batch, rewards_batch, next_states_batch, dones_batch = replay_buffer.sample(batch_size)

                states_batch = states_batch.to(device)
                next_states_batch = next_states_batch.to(device)
                actions_batch = actions_batch.to(device)
                rewards_batch = rewards_batch.to(device)
                dones_batch = dones_batch.to(device)

                # Flatten batch: [B, ...] -> [B, state_size]
                states_flat = states_batch.flatten(start_dim=1)
                next_states_flat = next_states_batch.flatten(start_dim=1)

                # 1. Current Q
                q_values_all = policy_net(states_flat)
                current_q_per_head = q_values_all * actions_batch
                current_q_total = current_q_per_head.sum(dim=2).sum(dim=1)

                # 2. Target Q
                with torch.no_grad():
                    next_q_values_all = target_net(next_states_flat)

                    # Masking Target
                    if current_num_nodes < next_q_values_all.shape[-1]:
                        next_q_values_all[..., current_num_nodes:] = -float('inf')

                    next_q_values_per_head = next_q_values_all.max(dim=2)[0]
                    next_q_total = next_q_values_per_head.sum(dim=1)
                    targets = rewards_batch.squeeze(1) + (1 - dones_batch.squeeze(1)) * gamma * next_q_total

                # 3. Loss & Step
                loss = nn.MSELoss()(current_q_total, targets)
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0)
                optimizer.step()

        # --- Update Target Net ---
        if episode % 10 == 0:
            target_net.load_state_dict(policy_net.state_dict())

        epsilon = max(epsilon_end, epsilon * epsilon_decay)

        # --- Logging ---
        if episode % interval_check == 0:
            placement = []
            for i in range(num_honeypots_N):
                try:
                    node_idx = np.argmax(action[i])
                    if node_idx < len(env.nodes):
                        node_name = env.nodes[node_idx]
                    else:
                        node_name = "INVALID_PADDING"
                except:
                    node_name = "ERROR"
                placement.append(f"Honeypot {i} -> {node_name}\n")

            print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon:.3f}, DSP: {dsp/interval_check*100:.3f}%")
            print("".join(placement))
            print(f"Path: {path}")
            total_reward = 0
            if dsp > best_dsp:
                best_dsp = dsp
                best_episode = episode
                best_checkpoint = {
                    'policy_net_state_dict': deepcopy(policy_net.state_dict()),
                    'target_net_state_dict': deepcopy(target_net.state_dict()),
                    'optimizer_state_dict': deepcopy(optimizer.state_dict()),
                }
            dsp = 0

        # --- Save Model ---
        if (episode + 1) % interval_save == 0 and best_checkpoint is not None:
            os.makedirs('./Saved_Model', exist_ok=True)
            path_save = f'./Saved_Model/dqn_model.pth'
            torch.save({
                'policy_net_state_dict': best_checkpoint['policy_net_state_dict'],
                'target_net_state_dict': best_checkpoint['target_net_state_dict'],
                'optimizer_state_dict': best_checkpoint['optimizer_state_dict'],
                'episode': best_episode},
                path_save)
            print(f'Saved model with best DSP {best_dsp} at episode {best_episode} to {path_save}')
            best_dsp = 0
            best_episode = 0
            best_checkpoint = None

    return policy_net

# %%
from copy import deepcopy
import numpy as np
from utils.graph_utils import *

# --- CẤU HÌNH ---
NUM_RUNS = 400           # Số lần chạy lặp lại
TRAIN_EPISODES = 5000   # Số episode huấn luyện
EVAL_EPISODES = 2000    # Số episode đánh giá (theo yêu cầu)

dsp_history = []        # List chứa kết quả DSP của 10 lần

print(f"=== BẮT ĐẦU CHẠY THỰC NGHIỆM ({NUM_RUNS} LẦN) ===")

for run_idx in range(1, NUM_RUNS + 1):
    print(f"\n" + "="*50)
    print(f" RUN {run_idx}/{NUM_RUNS}")
    print("="*50)

    # 1. RESET MÔI TRƯỜNG (Quan trọng: Phải tạo bản sao mới của đồ thị)
    # ----------------------------------------------------------------
    G_run = deepcopy(G_original)  # Copy từ đồ thị gốc ban đầu

    # Đảm bảo tensor feature
    nfeats_tensor = build_batch_tensor(nfeats, MAX_N_FEATURES).to(device)
    efeats_tensor = build_batch_tensor(efeats, MAX_E_FEATURES).to(device)

    env = NetworkEnv(
        G_new=G_run,
        attack_fn=global_weighted_random_attack, # Hoặc algo bạn chọn
        g_dgl=g_dgl.to(device),
        encoder=trained_encoder,
        original_node_features=nfeats_tensor,
        original_edge_features=efeats_tensor,
        node_map=node_map,
        num_honeypots=4,
        max_nodes=24,
        max_edges=200
    )

    # 2. HUẤN LUYỆN (Train)
    # ----------------------------------------------------------------
    print(f"Dang train ({TRAIN_EPISODES} episodes)...")
    # Hàm train_dqn sẽ tạo model mới bên trong nó
    model = train_dqn(env, TRAIN_EPISODES, device)

    # 3. ĐÁNH GIÁ (Evaluate)
    # ----------------------------------------------------------------
    print(f"Dang evaluate ({EVAL_EPISODES} episodes)...")

    # Gọi hàm evaluate_model (đã sửa ở trên để có return)
    final_dsp = evaluate_model(model, env, EVAL_EPISODES, device)

    # Lưu kết quả
    dsp_history.append(final_dsp)

# --- TỔNG KẾT ---
print("\n" + "#"*50)
print(" KẾT QUẢ TỔNG HỢP SAU 10 LẦN CHẠY")
print("#"*50)
print(f"Các giá trị DSP (%): {dsp_history}")

avg_dsp = np.mean(dsp_history)
max_dsp = np.max(dsp_history)
min_dsp = np.min(dsp_history)
std_dsp = np.std(dsp_history)

print(f"\nTrung bình DSP: {avg_dsp:.2f}%")
print(f"Cao nhất DSP:   {max_dsp:.2f}%")
print(f"Thấp nhất DSP:  {min_dsp:.2f}%")
print(f"Độ lệch chuẩn:  {std_dsp:.2f}")
# Out:
# === BẮT ĐẦU CHẠY THỰC NGHIỆM (2 LẦN) ===
#
# ==================================================
#  RUN 1/2
# ==================================================
# node_to_idx đã được tải: {'Data Server': 0, 'Pad': 1, 'Web Server': 2, 'Host 1': 3, 'Host 2': 4, 'Host 3': 5, 'File Server': 6, 'Print Server': 7}
# Mục tiêu (Goals) được thiết lập: ['Data Server']
# Số lượng honeypot (N) được thiết lập: 3
# Số lượng nút đặt (M) được thiết lập: 8
# Dang train (5000 episodes)...
# tensor([[-0.0034,  0.9064,  1.0525,  ...,  0.9012, -0.0034, -0.0092],
#         [-0.0023,  0.7742,  0.8983,  ...,  0.7635, -0.0026, -0.0079],
#         [-0.0023,  0.7742,  0.8983,  ...,  0.7635, -0.0026, -0.0079],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# Embedding Dim: 2
# Actual State Shape from Env: torch.Size([5376])
# Calculated State Size (Input to DQN): 5376
# Action Output Shape: (3, 24)
# Episode 500, Total Reward: 52, Epsilon: 0.082, DSP: 55.200%
# Honeypot 0 -> Pad
# Honeypot 1 -> Print Server
# Honeypot 2 -> Web Server
#
# Path: ['Pad', 'Host 1', 'Host 2', 'Host 3', 'Data Server']
# Saved model with best DSP 276 at episode 500 to ./Saved_Model/dqn_model.pth
# Episode 1000, Total Reward: 150, Epsilon: 0.010, DSP: 65.000%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 2
# Honeypot 2 -> Web Server
#
# Path: ['Web Server', 'Data Server']
# Episode 1500, Total Reward: 128, Epsilon: 0.010, DSP: 62.800%
# Honeypot 0 -> Pad
# Honeypot 1 -> Web Server
# Honeypot 2 -> Host 2
#
# Path: ['Web Server', 'Honeypot {Web Server}']
# Saved model with best DSP 325 at episode 1000 to ./Saved_Model/dqn_model.pth
# Episode 2000, Total Reward: 170, Epsilon: 0.010, DSP: 67.000%
# Honeypot 0 -> Pad
# Honeypot 1 -> Print Server
# Honeypot 2 -> Web Server
#
# Path: ['Host 1', 'Web Server', 'Pad', 'Host 2', 'Data Server']
# Episode 2500, Total Reward: 200, Epsilon: 0.010, DSP: 70.000%
# Honeypot 0 -> Pad
# Honeypot 1 -> Web Server
# Honeypot 2 -> Host 1
#
# Path: ['Host 1', 'Honeypot {Host 1}']
# Saved model with best DSP 350 at episode 2500 to ./Saved_Model/dqn_model.pth
# Episode 3000, Total Reward: 202, Epsilon: 0.010, DSP: 70.200%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 2
# Honeypot 2 -> Web Server
#
# Path: ['Web Server', 'Honeypot {Web Server}']
# Episode 3500, Total Reward: 164, Epsilon: 0.010, DSP: 66.400%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Web Server
# Honeypot 2 -> Pad
#
# Path: ['Pad', 'Web Server', 'Host 1', 'Host 3', 'Honeypot {Web Server}']
# Saved model with best DSP 351 at episode 3000 to ./Saved_Model/dqn_model.pth
# Episode 4000, Total Reward: 200, Epsilon: 0.010, DSP: 70.000%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Web Server
# Honeypot 2 -> Pad
#
# Path: ['Web Server', 'File Server', 'Data Server']
# Episode 4500, Total Reward: 220, Epsilon: 0.010, DSP: 72.000%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Web Server
# Honeypot 2 -> Pad
#
# Path: ['Host 1', 'Web Server', 'Host 3', 'Data Server']
# Saved model with best DSP 360 at episode 4500 to ./Saved_Model/dqn_model.pth
# Episode 5000, Total Reward: 214, Epsilon: 0.010, DSP: 71.400%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Web Server
# Honeypot 2 -> Pad
#
# Path: ['Web Server', 'File Server', 'Data Server']
# Dang evaluate (2000 episodes)...
# Đang đánh giá trên device: cuda
# Đang đánh giá... Kiến trúc Multi-Head (N=3 honeypots, M=8 nút)
# --- Episode 50: Failed ---
# ['Host 1', 'Web Server', 'Pad', 'Host 3', 'Host 2', 'Print Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 100: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 100/2000 episodes...
# --- Episode 150: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 200: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 200/2000 episodes...
# --- Episode 250: Success ---
# ['Host 1', 'Host 3', 'Pad', 'Print Server', 'Host 2', 'Web Server', 'File Server', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 300: Success ---
# ['Pad', 'Web Server', 'Host 1', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 300/2000 episodes...
# --- Episode 350: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 400: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 400/2000 episodes...
# --- Episode 450: Success ---
# ['Web Server', 'File Server', 'Print Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 500: Failed ---
# ['Host 1', 'Host 3', 'Host 2', 'File Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 500/2000 episodes...
# --- Episode 550: Success ---
# ['Host 1', 'Pad', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 600: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 600/2000 episodes...
# --- Episode 650: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 700: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 700/2000 episodes...
# --- Episode 750: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 800: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 800/2000 episodes...
# --- Episode 850: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 900: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 900/2000 episodes...
# --- Episode 950: Success ---
# ['Host 1', 'Web Server', 'Pad', 'File Server', 'Host 3', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1000: Failed ---
# ['Web Server', 'File Server', 'Print Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1000/2000 episodes...
# --- Episode 1050: Success ---
# ['Host 1', 'Host 3', 'Host 2', 'Print Server', 'File Server', 'Pad', 'Web Server', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1100: Success ---
# ['Web Server', 'File Server', 'Print Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1100/2000 episodes...
# --- Episode 1150: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1200: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1200/2000 episodes...
# --- Episode 1250: Success ---
# ['Web Server', 'File Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1300: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1300/2000 episodes...
# --- Episode 1350: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1400: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1400/2000 episodes...
# --- Episode 1450: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1500: Success ---
# ['Web Server', 'File Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1500/2000 episodes...
# --- Episode 1550: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1600: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1600/2000 episodes...
# --- Episode 1650: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1700: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1700/2000 episodes...
# --- Episode 1750: Failed ---
# ['Pad', 'Host 2', 'Host 1', 'Host 3', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1800: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1800/2000 episodes...
# --- Episode 1850: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 1900: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 1900/2000 episodes...
# --- Episode 1950: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# --- Episode 2000: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Host 1', 'Web Server', 'Pad']
#
# Đã hoàn thành 2000/2000 episodes...
#
# --- Evaluation Complete ---
# Defense success probability: 71.300% (1426/2000)
#
# ==================================================
#  RUN 2/2
# ==================================================
# node_to_idx đã được tải: {'Data Server': 0, 'Pad': 1, 'Web Server': 2, 'Host 1': 3, 'Host 2': 4, 'Host 3': 5, 'File Server': 6, 'Print Server': 7}
# Mục tiêu (Goals) được thiết lập: ['Data Server']
# Số lượng honeypot (N) được thiết lập: 3
# Số lượng nút đặt (M) được thiết lập: 8
# Dang train (5000 episodes)...
# tensor([[-0.0034,  0.9064,  1.0525,  ...,  0.9012, -0.0034, -0.0092],
#         [-0.0023,  0.7742,  0.8983,  ...,  0.7635, -0.0026, -0.0079],
#         [-0.0023,  0.7742,  0.8983,  ...,  0.7635, -0.0026, -0.0079],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# Embedding Dim: 2
# Actual State Shape from Env: torch.Size([5376])
# Calculated State Size (Input to DQN): 5376
# Action Output Shape: (3, 24)
# Episode 500, Total Reward: 116, Epsilon: 0.082, DSP: 61.600%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 1
# Honeypot 2 -> Web Server
#
# Path: ['Host 1', 'Web Server', 'Pad', 'Honeypot {Host 1}']
# Saved model with best DSP 308 at episode 500 to ./Saved_Model/dqn_model.pth
# Episode 1000, Total Reward: 162, Epsilon: 0.010, DSP: 66.200%
# Honeypot 0 -> Web Server
# Honeypot 1 -> Pad
# Honeypot 2 -> Host 1
#
# Path: ['Pad', 'Host 2', 'Host 3', 'Print Server', 'File Server', 'Data Server']
# Episode 1500, Total Reward: 170, Epsilon: 0.010, DSP: 67.000%
# Honeypot 0 -> Web Server
# Honeypot 1 -> Pad
# Honeypot 2 -> Host 1
#
# Path: ['Web Server', 'Honeypot {Web Server}']
# Saved model with best DSP 335 at episode 1500 to ./Saved_Model/dqn_model.pth
# Episode 2000, Total Reward: 200, Epsilon: 0.010, DSP: 70.000%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Pad
# Honeypot 2 -> Web Server
#
# Path: ['Web Server', 'Honeypot {Web Server}']
# Episode 2500, Total Reward: 210, Epsilon: 0.010, DSP: 71.000%
# Honeypot 0 -> Web Server
# Honeypot 1 -> Pad
# Honeypot 2 -> Host 1
#
# Path: ['Host 1', 'Web Server', 'Host 3', 'Print Server', 'Host 2', 'Data Server']
# Saved model with best DSP 355 at episode 2500 to ./Saved_Model/dqn_model.pth
# Episode 3000, Total Reward: 222, Epsilon: 0.010, DSP: 72.200%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 1
# Honeypot 2 -> Web Server
#
# Path: ['Web Server', 'File Server', 'Data Server']
# Episode 3500, Total Reward: 212, Epsilon: 0.010, DSP: 71.200%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 1
# Honeypot 2 -> Web Server
#
# Path: ['Host 1', 'Web Server', 'Data Server']
# Saved model with best DSP 361 at episode 3000 to ./Saved_Model/dqn_model.pth
# Episode 4000, Total Reward: 184, Epsilon: 0.010, DSP: 68.400%
# Honeypot 0 -> Pad
# Honeypot 1 -> Host 1
# Honeypot 2 -> Web Server
#
# Path: ['Host 1', 'Host 2', 'Honeypot {Host 1}']
# Episode 4500, Total Reward: 218, Epsilon: 0.010, DSP: 71.800%
# Honeypot 0 -> Host 1
# Honeypot 1 -> Pad
# Honeypot 2 -> Web Server
#
# Path: ['Host 1', 'Host 2', 'Data Server']
# Saved model with best DSP 359 at episode 4500 to ./Saved_Model/dqn_model.pth
# Episode 5000, Total Reward: 248, Epsilon: 0.010, DSP: 74.800%
# Honeypot 0 -> Web Server
# Honeypot 1 -> Pad
# Honeypot 2 -> Host 1
#
# Path: ['Host 1', 'Pad', 'Honeypot {Pad}']
# Dang evaluate (2000 episodes)...
# Đang đánh giá trên device: cuda
# Đang đánh giá... Kiến trúc Multi-Head (N=3 honeypots, M=8 nút)
# --- Episode 50: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 100: Failed ---
# ['Web Server', 'File Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 100/2000 episodes...
# --- Episode 150: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 200: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 200/2000 episodes...
# --- Episode 250: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 300: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 300/2000 episodes...
# --- Episode 350: Failed ---
# ['Pad', 'Host 2', 'File Server', 'Web Server', 'Host 3', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 400: Success ---
# ['Pad', 'Host 2', 'Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 400/2000 episodes...
# --- Episode 450: Failed ---
# ['Web Server', 'File Server', 'Print Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 500: Failed ---
# ['Web Server', 'File Server', 'Print Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 500/2000 episodes...
# --- Episode 550: Success ---
# ['Host 1', 'Host 2', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 600: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 600/2000 episodes...
# --- Episode 650: Failed ---
# ['Pad', 'Host 3', 'Web Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 700: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 700/2000 episodes...
# --- Episode 750: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 800: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 800/2000 episodes...
# --- Episode 850: Success ---
# ['Host 1', 'Pad', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 900: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 900/2000 episodes...
# --- Episode 950: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1000: Success ---
# ['Web Server', 'File Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1000/2000 episodes...
# --- Episode 1050: Success ---
# ['Host 1', 'Pad', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1100: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1100/2000 episodes...
# --- Episode 1150: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1200: Failed ---
# ['Pad', 'Web Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1200/2000 episodes...
# --- Episode 1250: Failed ---
# ['Pad', 'Web Server', 'Host 3', 'Host 2', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1300: Success ---
# ['Pad', 'Host 3', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1300/2000 episodes...
# --- Episode 1350: Success ---
# ['Host 1', 'Pad', 'Web Server', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1400: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1400/2000 episodes...
# --- Episode 1450: Failed ---
# ['Host 1', 'Web Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1500: Failed ---
# ['Web Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1500/2000 episodes...
# --- Episode 1550: Failed ---
# ['Pad', 'Host 3', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1600: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1600/2000 episodes...
# --- Episode 1650: Success ---
# ['Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1700: Failed ---
# ['Host 1', 'Web Server', 'Data Server']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1700/2000 episodes...
# --- Episode 1750: Success ---
# ['Pad', 'Honeypot {Pad}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1800: Success ---
# ['Pad', 'Web Server', 'Honeypot {Pad}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1800/2000 episodes...
# --- Episode 1850: Success ---
# ['Host 1', 'Host 3', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 1900: Success ---
# ['Host 1', 'Honeypot {Host 1}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 1900/2000 episodes...
# --- Episode 1950: Success ---
# ['Pad', 'Host 1', 'Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# --- Episode 2000: Success ---
# ['Web Server', 'Honeypot {Web Server}']
# Honeypots connected to: ['Web Server', 'Pad', 'Host 1']
#
# Đã hoàn thành 2000/2000 episodes...
#
# --- Evaluation Complete ---
# Defense success probability: 72.350% (1447/2000)
#
# ##################################################
#  KẾT QUẢ TỔNG HỢP SAU 10 LẦN CHẠY
# ##################################################
# Các giá trị DSP (%): [71.3, 72.35000000000001]
#
# Trung bình DSP: 71.83%
# Cao nhất DSP:   72.35%
# Thấp nhất DSP:  71.30%
# Độ lệch chuẩn:  0.53

# %%
saved_path = save_graph_env(
    experiment_id=experiment_id,
    G_nx=G_original,
    nfeats=nfeats,
    efeats=efeats,
    node_order=node_order,
    base_dir='graphs'
)
# Out:
# Đang xử lý lưu dữ liệu vào thư mục: graphs/1
#  >> Đã lưu Môi trường Tĩnh (env_data) vào: graphs/1/graph_environment.pth

# %%
plt.figure(figsize=(30, 36))
pos = nx.spring_layout(G_original) # Dùng G_original

nx.draw_networkx_nodes(G_original, pos, node_color='orange', node_size=2000)
nx.draw_networkx_labels(G_original, pos, font_size=10, font_weight='bold')

nx.draw_networkx_edges(
    G_original, pos,
    edge_color='gray',
    arrows=True,
    arrowstyle='->',
    arrowsize=50,
    connectionstyle='arc3,rad=0.2'
)

# Vẽ nhãn trên cạnh
edge_labels = {(u, v): f"user={d['user']}, root={d['root']}" for u, v, d in G_original.edges(data=True)}
nx.draw_networkx_edge_labels(G_original, pos, edge_labels=edge_labels, font_size=12)

plt.axis('off')
plt.show()
